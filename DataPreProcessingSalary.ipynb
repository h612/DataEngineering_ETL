# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
salary_file = "Raw Data\salary.csv"
salary_df = pd.read_csv(salary_file)
salary_df.head(10)
# Out:
#                      Australian Bureau of Statistics  \
# 0  Personal Income in Australia Table 1. Total In...
# 1    Released at 11:30 am (Canberra time) 16/12/2020
# 2                                          Table 1.5
# 3                                                NaN
# 4                                                NaN
# 5                                                LGA
# 6                                         Australia
# 7                                    New South Wales
# 8                                              10050
# 9                                              10130
#
#                                           Unnamed: 1         Unnamed: 2  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  Total Income by Local Government Area (2011-12...                NaN
# 3                                                NaN                NaN
# ...

# %%
salary_df
# Out:
#                         Australian Bureau of Statistics  \
# 0     Personal Income in Australia Table 1. Total In...
# 1       Released at 11:30 am (Canberra time) 16/12/2020
# 2                                             Table 1.5
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2296                                                NaN
# 2297                                                NaN
# 2298                                                NaN
# 2299                                                NaN
# 2300                                                NaN
#
#                                              Unnamed: 1         Unnamed: 2  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# ...

# %%
salary_df=salary_df.drop([0,1,2,3,4])

# %%
salary_df
# Out:
#                  Australian Bureau of Statistics         Unnamed: 1  \
# 5                                            LGA           LGA NAME
# 6                                     Australia                 NaN
# 7                                New South Wales                NaN
# 8                                          10050             Albury
# 9                                          10130  Armidale Regional
# ...                                          ...                ...
# 2296                                         NaN                NaN
# 2297                                         NaN                NaN
# 2298                                         NaN                NaN
# 2299                                         NaN                NaN
# 2300                                         NaN                NaN
#
#         Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6  \
# ...

# %%
salary_df.columns=salary_df.iloc[0]

# %%
salary_df
# Out:
# 5                 LGA           LGA NAME       2011-12       2012-13  \
# 5                 LGA           LGA NAME       2011-12       2012-13
# 6          Australia                 NaN   12,268,900    12,449,976
# 7     New South Wales                NaN    3,824,011     3,871,906
# 8               10050             Albury       26,948        27,054
# 9               10130  Armidale Regional       14,679        14,623
# ...               ...                ...           ...           ...
# 2296              NaN                NaN           NaN           NaN
# 2297              NaN                NaN           NaN           NaN
# 2298              NaN                NaN           NaN           NaN
# 2299              NaN                NaN           NaN           NaN
# 2300              NaN                NaN           NaN           NaN
#
# 5          2013-14       2014-15       2015-16       2016-17       2017-18  \
# ...

# %%
salary_df=salary_df.drop([5])

# %%
salary_df
# Out:
# 5                 LGA           LGA NAME       2011-12       2012-13  \
# 6          Australia                 NaN   12,268,900    12,449,976
# 7     New South Wales                NaN    3,824,011     3,871,906
# 8               10050             Albury       26,948        27,054
# 9               10130  Armidale Regional       14,679        14,623
# 10              10250            Ballina       22,308        22,240
# ...               ...                ...           ...           ...
# 2296              NaN                NaN           NaN           NaN
# 2297              NaN                NaN           NaN           NaN
# 2298              NaN                NaN           NaN           NaN
# 2299              NaN                NaN           NaN           NaN
# 2300              NaN                NaN           NaN           NaN
#
# 5          2013-14       2014-15       2015-16       2016-17       2017-18  \
# ...

# %%
salary_df2=salary_df.iloc[:, [0,1,27,28,29]]

# %%
salary_df2
# Out:
# 5                 LGA           LGA NAME   2015-16   2016-17   2017-18
# 6          Australia                 NaN   47,692    48,360    49,805
# 7     New South Wales                NaN   48,085    48,700    50,153
# 8               10050             Albury   45,504    46,426    47,732
# 9               10130  Armidale Regional   40,733    41,120    42,220
# 10              10250            Ballina   39,782    40,362    42,246
# ...               ...                ...       ...       ...       ...
# 2296              NaN                NaN       NaN       NaN       NaN
# 2297              NaN                NaN       NaN       NaN       NaN
# 2298              NaN                NaN       NaN       NaN       NaN
# 2299              NaN                NaN       NaN       NaN       NaN
# 2300              NaN                NaN       NaN       NaN       NaN
#
# [2295 rows x 5 columns]

# %%
salary_df.shape

# %%
salary_df2.head(10)
# Out:
# 5               LGA           LGA NAME   2015-16   2016-17   2017-18
# 6        Australia                 NaN   47,692    48,360    49,805
# 7   New South Wales                NaN   48,085    48,700    50,153
# 8             10050             Albury   45,504    46,426    47,732
# 9             10130  Armidale Regional   40,733    41,120    42,220
# 10            10250            Ballina   39,782    40,362    42,246
# 11            10300          Balranald   42,282    45,080    46,868
# 12            10470  Bathurst Regional   47,746    48,373    49,633
# 13            10500            Bayside   47,809    48,383    49,445
# 14            10550        Bega Valley   37,270    37,366    38,318
# 15            10600          Bellingen   35,835    36,601    35,924

# %%
salary_df2.dropna()
# Out:
# 5      LGA            LGA NAME   2015-16   2016-17   2017-18
# 8    10050              Albury   45,504    46,426    47,732
# 9    10130   Armidale Regional   40,733    41,120    42,220
# 10   10250             Ballina   39,782    40,362    42,246
# 11   10300           Balranald   42,282    45,080    46,868
# 12   10470   Bathurst Regional   47,746    48,373    49,633
# ..     ...                 ...       ...       ...       ...
# 548  74550       Victoria Daly   39,614    37,481    35,928
# 549  74560              Wagait   60,000    61,366    62,104
# 550  74660         West Arnhem   55,504    52,509    47,876
# 551  74680           West Daly   33,482    29,027    32,812
# 553  89399  Unincorporated ACT   63,061    63,031    64,321
#
# [539 rows x 5 columns]

# %%
salary_df2.head(20)

# %%
salary_df3= salary_df2.rename(columns={'LGA NAME':'LGA_NAME'})

# %%
salary_df3
# Out:
# 5                 LGA           LGA_NAME   2015-16   2016-17   2017-18
# 6          Australia                 NaN   47,692    48,360    49,805
# 7     New South Wales                NaN   48,085    48,700    50,153
# 8               10050             Albury   45,504    46,426    47,732
# 9               10130  Armidale Regional   40,733    41,120    42,220
# 10              10250            Ballina   39,782    40,362    42,246
# ...               ...                ...       ...       ...       ...
# 2296              NaN                NaN       NaN       NaN       NaN
# 2297              NaN                NaN       NaN       NaN       NaN
# 2298              NaN                NaN       NaN       NaN       NaN
# 2299              NaN                NaN       NaN       NaN       NaN
# 2300              NaN                NaN       NaN       NaN       NaN
#
# [2295 rows x 5 columns]

# %%
salary_df3 = salary_df2.reset_index(drop=True)

# %%
salary_df3
# Out:
# 5                 LGA           LGA NAME   2015-16   2016-17   2017-18
# 0          Australia                 NaN   47,692    48,360    49,805
# 1     New South Wales                NaN   48,085    48,700    50,153
# 2               10050             Albury   45,504    46,426    47,732
# 3               10130  Armidale Regional   40,733    41,120    42,220
# 4               10250            Ballina   39,782    40,362    42,246
# ...               ...                ...       ...       ...       ...
# 2290              NaN                NaN       NaN       NaN       NaN
# 2291              NaN                NaN       NaN       NaN       NaN
# 2292              NaN                NaN       NaN       NaN       NaN
# 2293              NaN                NaN       NaN       NaN       NaN
# 2294              NaN                NaN       NaN       NaN       NaN
#
# [2295 rows x 5 columns]

# %%
salary_df3 = salary_df2.fillna(0)

# %%
str_col = ['LGA','LGA NAME','2015-16','2016-17','2017-18']
salary_df3[str_col] = salary_df3[str_col].replace('np',0,regex=True)

# %%
salary_df3
# Out:
# 5                 LGA           LGA NAME   2015-16   2016-17   2017-18
# 0          Australia                 NaN   47,692    48,360    49,805
# 1     New South Wales                NaN   48,085    48,700    50,153
# 2               10050             Albury   45,504    46,426    47,732
# 3               10130  Armidale Regional   40,733    41,120    42,220
# 4               10250            Ballina   39,782    40,362    42,246
# ...               ...                ...       ...       ...       ...
# 2290              NaN                NaN       NaN       NaN       NaN
# 2291              NaN                NaN       NaN       NaN       NaN
# 2292              NaN                NaN       NaN       NaN       NaN
# 2293              NaN                NaN       NaN       NaN       NaN
# 2294              NaN                NaN       NaN       NaN       NaN
#
# [2295 rows x 5 columns]

# %%
salary_df3.index.isna()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
finaldf = salary_df3.dropna(subset = ["LGA NAME"])

# %%
finaldf = finaldf.reset_index(drop=True)

# %%
finaldf.to_csv('salaryClean.csv')
