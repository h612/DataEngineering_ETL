# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
school_file = "DestinationData2020.csv"
school_df = pd.read_csv(school_file)
school_df.head()
# Out:
#   Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools  \
# 0  Source: On Track Year 12 completer survey 2020...
# 1                                                NaN
# 2                                          VCAA CODE
# 3                                                NaN
# 4                                                NaN
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3               Unnamed: 4  \
# 0          NaN        NaN        NaN                      NaN
# 1          NaN        NaN        NaN                      NaN
# 2  SCHOOL NAME     SECTOR   LOCALITY  TOTAL COMPLETED YEAR 12
# 3          NaN        NaN        NaN                      NaN
# 4          NaN        NaN        NaN                      NaN
#
#             Unnamed: 5                    Unnamed: 6  \
# 0                  NaN                           NaN
# 1                  NaN                           NaN
# 2  ON TRACK CONSENTERS  ON TRACK SURVEY DATA 2020 **
# ...

# %%
school_df=school_df[3:]
school_df.head()
# Out:
#   Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools  \
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                              01006
# 7                                              01008
#
#            Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3                 NaN        NaN            NaN        NaN        NaN
# 4                 NaN        NaN            NaN        NaN        NaN
# 5                 NaN        NaN            NaN   (NUMBER)   (NUMBER)
# 6     SUNBURY COLLEGE          G        SUNBURY        109        109
# 7  AUBURN HIGH SCHOOL          G  HAWTHORN EAST         33         32
#
#               Unnamed: 6                            Unnamed: 7  Unnamed: 8  \
# 3  ON TRACK RESPONDENTS*  IN EDUCATION AND TRAINING - MAY 2020         NaN
# ...

# %%
temp=school_df

# %%
temp
# Out:
#     Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools  \
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                01006
# 7                                                01008
# ..                                                 ...
# 387  Not all schools are included in the table. The...
# 388   - Schools with less than 10 Year 12 completer...
# 389   - Schools with less than 50% consent rate, le...
# 390                                                NaN
# 391  See explanatory notes for further information ...
#
#              Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3                   NaN        NaN            NaN        NaN        NaN
# 4                   NaN        NaN            NaN        NaN        NaN
# ...

# %%
temp.columns
# Out:
# Index(['Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
temp
# Out:
#     Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools  \
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                01006
# 7                                                01008
# ..                                                 ...
# 387  Not all schools are included in the table. The...
# 388   - Schools with less than 10 Year 12 completer...
# 389   - Schools with less than 50% consent rate, le...
# 390                                                NaN
# 391  See explanatory notes for further information ...
#
#              Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3                   NaN        NaN            NaN        NaN        NaN
# 4                   NaN        NaN            NaN        NaN        NaN
# ...

# %%
temp1=temp.rename(columns={'Post School Destinations of Year 12 or equivalent completers in 2019, Victorian schools':'VCAA_CODE',
                           'Unnamed: 1':'SCHOOL_NAME',
                            'Unnamed: 2':'SECTOR',
                            'Unnamed: 3':'LOCALITY',
                            'Unnamed: 4':'TOTAL_COMPLETED_YEAR_12',
                            'Unnamed: 5':'ON_TRACK_CONSENTERS',
                            'Unnamed: 6':'ON_TRACK_RESPONDENTS',
                            'Unnamed: 7':'BACHELOR_ENROLLED',
                            'Unnamed: 8':'DEFERRED',
                            'Unnamed: 9':'TAFE_VET_ENROLLED',
                            'Unnamed: 10':'APPRENTICE_TRAINEE',
                            'Unnamed: 11':'EMPLOYED',
                            'Unnamed: 12':'LOOKING_FOR_WORK',
                            'Unnamed: 13':'Other'})

# %%
df=temp1.drop(['Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],axis=1)

# %%
df
# Out:
#                                              VCAA_CODE         SCHOOL_NAME  \
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# 5                                                  NaN                 NaN
# 6                                                01006     SUNBURY COLLEGE
# 7                                                01008  AUBURN HIGH SCHOOL
# ..                                                 ...                 ...
# 387  Not all schools are included in the table. The...                 NaN
# 388   - Schools with less than 10 Year 12 completer...                 NaN
# 389   - Schools with less than 50% consent rate, le...                 NaN
# 390                                                NaN                 NaN
# 391  See explanatory notes for further information ...                 NaN
#
# ...

# %%
df=df.drop([3,4,5])

# %%
df=df[:371]

# %%
df
# Out:
#     VCAA_CODE                   SCHOOL_NAME SECTOR                  LOCALITY  \
# 6       01006               SUNBURY COLLEGE      G                   SUNBURY
# 7       01008            AUBURN HIGH SCHOOL      G             HAWTHORN EAST
# 8       01011  MCCLELLAND SECONDARY COLLEGE      G           FRANKSTON NORTH
# 9       01012           TIMBOON P-12 SCHOOL      G       CORANGAMITE - SOUTH
# 10      01015     METHODIST LADIES' COLLEGE      I                       KEW
# ..        ...                           ...    ...                       ...
# 372     15120        TARNEIT SENIOR COLLEGE      G                   TARNEIT
# 373     15343        MARIST COLLEGE BENDIGO      C              MAIDEN GULLY
# 374     15395                  ILIM COLLEGE      I  CAMPBELLFIELD - COOLAROO
# 375     15458      HAILEYBURY GIRLS COLLEGE      I           NORTH MELBOURNE
# 376      1606      KANGAN INSTITUTE OF TAFE      A              BROADMEADOWS
#
# ...

# %%
df=df.reset_index(drop=True)

# %%
df.to_csv('destination_school.csv')
